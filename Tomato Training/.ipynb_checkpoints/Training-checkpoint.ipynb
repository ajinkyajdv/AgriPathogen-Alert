# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 50

# %%
#Tensorflow Input Pipeline
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Sample",
    shuffle = True,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 4000 files belonging to 4 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Bacterial_spot',
#  'Tomato___healthy',
#  'Tomato_mosaic_virus']

# %%
len(dataset)
# Out:
# 125

# %%
32 * 125
# Out:
# 4000

# %%
for image_batch, label_batch in dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# (32, 256, 256, 3)
# [1 2 2 1 1 3 1 0 1 2 1 1 1 1 0 0 2 1 0 3 3 1 0 0 0 2 2 1 0 0 1 3]

# %%
#Display First Image
for image_batch, label_batch in dataset.take(1):
    plt.imshow(image_batch[0].numpy().astype("uint8"))
    plt.title(class_names[label_batch[0]])
    plt.axis("off")

# %%
#Display more images

plt.figure(figsize = (15,15))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
len(dataset)
# Out:
# 125

# %%
80% ==> training
20% ==> 10% validation, 10% test

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 100.0

# %%
train_ds = dataset.take(100)
len(train_ds)
# Out:
# 100

# %%
test_ds = dataset.skip(100)
len(test_ds)
# Out:
# 25

# %%
val_size = 0.1
len(dataset)*val_size
# Out:
# 12.5

# %%
val_ds = test_ds.take(12)
len(val_ds)
# Out:
# 12

# %%
test_ds = test_ds.skip(12)
len(test_ds)
# Out:
# 13

# %%
#Partition function for above detailed explanation
def ds_partition_tf(ds, train_split = 0.8, val_split = 0.1, test_split = 0.1, shuffle=True, shuffle_size = 10000):
    
    ds_size = len(ds)
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size.skip(val_))
    
    return train_ds, val_ds, test_ds
